# %% [markdown]
# <a href="https://colab.research.google.com/github/laiscavalcanti/DataStructuresAndAlgorithms/blob/master/ImersaoDadosDaAlura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
import pandas as pd

fonte = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

dados = pd.read_csv(fonte)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
dados.shape
# Out:
# (127380, 136)

# %%
dados["SG_UF_RESIDENCIA"]
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
dados.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
dados["SG_UF_RESIDENCIA"].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
dados["SG_UF_RESIDENCIA"].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados["NU_IDADE"].value_counts()
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 75        2
# 73        2
# 82        1
# 77        1
# 76        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados["NU_IDADE"].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados[['NU_IDADE', 'SG_UF_RESIDENCIA']].value_counts().sort_index()
# Out:
# NU_IDADE  SG_UF_RESIDENCIA
# 13        AP                  1
#           BA                  1
#           MT                  1
#           SP                  1
# 14        AC                  1
#                              ..
# 73        SP                  1
# 75        BA                  2
# 76        BA                  1
# 77        RJ                  1
# 82        RJ                  1
# Length: 1333, dtype: int64

# %%
dados['NU_IDADE'].hist()

# %%
dados.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts(normalize=True)
# Out:
# PE    0.124138
# CE    0.103448
# BA    0.096552
# PA    0.082759
# SP    0.075862
# MG    0.075862
# MA    0.062069
# GO    0.048276
# PI    0.048276
# PB    0.048276
# MT    0.027586
# AM    0.027586
# DF    0.027586
# PR    0.020690
# TO    0.020690
# SE    0.020690
# AL    0.013793
# SC    0.013793
# RO    0.013793
# RS    0.006897
# RJ    0.006897
# RN    0.006897
# MS    0.006897
# ES    0.006897
# AC    0.006897
# AP    0.006897
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
dados['NU_IDADE'].hist(bins = 50, figsize= (10,8), legend= True)
plt.title("Análise gráfica das idades dos participantes do ENEM 2019", fontsize=25, color="Green")
# Out:
# Text(0.5, 1.0, 'Análise gráfica das idades dos participantes do ENEM 2019')

# %%
dados['IN_TREINEIRO']
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 127375    0
# 127376    0
# 127377    0
# 127378    0
# 127379    0
# Name: IN_TREINEIRO, Length: 127380, dtype: int64

# %%
dados.query('NU_IDADE == 13')['SG_UF_RESIDENCIA']
# Out:
# 57359     SP
# 95630     MT
# 98197     AP
# 116501    BA
# Name: SG_UF_RESIDENCIA, dtype: object

# %%
dados.query('IN_TREINEIRO == 1')['NU_IDADE'].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
dados.query('IN_TREINEIRO == 1')['NU_IDADE'].value_counts().hist(bins = 10, figsize= (10,8), legend= True)
plt.title("Gráfico que representa a quantidade de treineiros no Enem 2019", fontsize=25, color="Green")
# Out:
# Text(0.5, 1.0, 'Gráfico que representa a quantidade de treineiros no Enem 2019')

# %%
t_s = dados.query('IN_TREINEIRO == 1')['NU_IDADE']
t_n = dados.query('IN_TREINEIRO == 0')['NU_IDADE']


plot = t_s.hist(figsize=(18,5), bins=100, color='b',alpha=0.7, label='Treineiros')
plot = t_n.hist(figsize=(18,5), bins=100, color='r', alpha=0.7, label='Não Treineiros')


plot.legend(loc='lower right')
plot.set_title(label='Proporção de Treineiros por Idade', fontdict={'fontsize':20})
# Out:
# Text(0.5, 1.0, 'Proporção de Treineiros por Idade')

# %%
dados["NU_NOTA_REDACAO"].hist(bins = 20, figsize=(8, 6))

# %%
dados["NU_NOTA_LC"].hist(bins = 20, figsize=(8, 6))

# %%
dados["NU_NOTA_REDACAO"].std()
# Out:
# 188.07645455749753

# %%
dados["NU_NOTA_REDACAO"].mean()
# Out:
# 571.5700253970197

# %%
provas = ["NU_NOTA_REDACAO","NU_NOTA_CH", "NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_CN"]

dados[provas].describe()
# Out:
#        NU_NOTA_REDACAO    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC    NU_NOTA_CN
# count     98043.000000  98043.000000  92758.000000  98043.000000  92758.000000
# mean        571.570025    507.365912    523.555206    520.463928    477.964015
# std         188.076455     82.972839    109.416939     64.556578     76.296099
# min           0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         480.000000    447.900000    435.300000    483.700000    418.000000
# 50%         580.000000    510.900000    501.600000    526.100000    470.200000
# 75%         680.000000    567.100000    598.200000    565.100000    533.300000
# max        1000.000000    809.400000    985.000000    801.700000    797.300000

# %%
dados['NU_NOTA_CN'].quantile(0.1)
# Out:
# 383.3

# %%
dados['NU_NOTA_CN'].plot.box(grid= True, figsize=(8, 6))

# %%
dados[provas].plot.box(grid= True, figsize=(8, 6))

# %% [markdown]
# ## Aula 02

# %%
alunos_menor_quatorze  = dados.query("NU_IDADE <= 14")
alunos_menor_quatorze['SG_UF_RESIDENCIA'].value_counts().plot.pie(figsize=(10, 8))

# %%
lista = list(dados.query("NU_IDADE <= 14")['SG_UF_RESIDENCIA'].value_counts(normalize=True))

alunos_menor_quatorze  = dados.query("NU_IDADE <= 18")
alunos_menor_quatorze['SG_UF_RESIDENCIA'].value_counts(normalize=True).plot.bar(figsize=(10, 8))

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x="Q006", y= "NU_NOTA_MT", data = dados)
plt.title("Boxplot das notas de matemática pela renda familiar")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matemática pela renda familiar')

# %%
renda_ordenada = dados["Q006"].unique()
renda_ordenada.sort()

plt.figure(figsize=(10, 8))
sns.boxplot(x="Q006", y= "NU_NOTA_MT", data = dados, order = renda_ordenada)
plt.title("Boxplot das notas de matemática pela renda familiar", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matemática pela renda familiar')

# %%
dados[provas].sum()
# Out:
# NU_NOTA_REDACAO    56038440.0
# NU_NOTA_CH         49743676.1
# NU_NOTA_MT         48563933.8
# NU_NOTA_LC         51027844.9
# NU_NOTA_CN         44334986.1
# dtype: float64

# %%
dados[provas].sum(axis=1)
# Out:
# 0         2288.9
# 1         1184.6
# 2         2350.5
# 3         2555.7
# 4         2803.5
#            ...
# 127375    2867.4
# 127376    2218.5
# 127377    1453.9
# 127378    2573.9
# 127379    2287.8
# Length: 127380, dtype: float64

# %%
dados["NU_NOTA_TOTAL"] = dados[provas].sum(axis=1)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x="Q006", y= "NU_NOTA_TOTAL", data = dados, order = renda_ordenada)
plt.title("Boxplot das notas totais pela renda familiar", fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-63591bc2a303> in <module>()
#       1 plt.figure(figsize=(10, 8))
# ----> 2 sns.boxplot(x="Q006", y= "NU_NOTA_TOTAL", data = dados, order = renda_ordenada)
#       3 plt.title("Boxplot das notas totais pela renda familiar", fontsize=20)
#
# NameError: name 'renda_ordenada' is not defined

# %%
sns.displot(dados, x = "NU_NOTA_TOTAL")

# %%
provas.append("NU_NOTA_TOTAL")
dados.query("NU_NOTA_TOTAL == 0")
# Out:
#         NU_INSCRICAO  NU_ANO  ...  Q025 NU_NOTA_TOTAL
# 10      190001005028    2019  ...     A           0.0
# 11      190001005057    2019  ...     B           0.0
# 26      190001005484    2019  ...     B           0.0
# 38      190001006086    2019  ...     B           0.0
# 40      190001006292    2019  ...     B           0.0
# ...              ...     ...  ...   ...           ...
# 127351  190006118552    2019  ...     B           0.0
# 127365  190006119756    2019  ...     A           0.0
# 127366  190006119783    2019  ...     A           0.0
# 127368  190006119802    2019  ...     B           0.0
# 127374  190006119995    2019  ...     B           0.0
#
# [29162 rows x 137 columns]

# %%
provas.append("NU_NOTA_TOTAL")
zerados_por_estado = dados.query("NU_NOTA_TOTAL == 0")["SG_UF_RESIDENCIA"]
zerados_por_estado.value_counts().sort_index()
# Out:
# AC     217
# AL     484
# AM     898
# AP     247
# BA    2340
# CE    1609
# DF     600
# ES     624
# GO    1007
# MA    1216
# MG    3078
# MS     443
# MT     577
# PA    1619
# PB     693
# PE    1431
# PI     591
# PR    1245
# RJ    1943
# RN     623
# RO     375
# RR      89
# RS    1338
# SC     593
# SE     343
# SP    4676
# TO     263
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
Proporcao = dados['NU_IDADE'].value_counts()
Lista = []
for i in Proporcao:
  a = (i * 100) / 127379
  b = round(a,2)
  Lista.append(b)
Porcentagem = pd.DataFrame(Proporcao)
Porcentagem['Porcentagem'] = Lista
Porcentagem
# Out:
#     NU_IDADE  Porcentagem
# 18     21452        16.84
# 17     21256        16.69
# 19     14418        11.32
# 20     10413         8.17
# 16      7830         6.15
# ..       ...          ...
# 75         2         0.00
# 73         2         0.00
# 82         1         0.00
# 77         1         0.00
# 76         1         0.00
#
# [65 rows x 2 columns]

# %%
dados_sem_notas_zero = dados[provas].query("NU_NOTA_TOTAL != 0")
dados_sem_notas_zero.head()
# Out:
#    NU_NOTA_REDACAO  NU_NOTA_CH  ...  NU_NOTA_TOTAL  NU_NOTA_TOTAL
# 0            420.0       512.3  ...        32044.6        32044.6
# 1            400.0       409.3  ...        16584.4        16584.4
# 2            560.0       499.1  ...        32907.0        32907.0
# 3            500.0       578.1  ...        35779.8        35779.8
# 4            780.0       571.3  ...        39249.0        39249.0
#
# [5 rows x 18 columns]

# %%
dados_sem_notas_zero = dados.query("NU_NOTA_TOTAL != 0")

dados_sem_notas_zero.head()

plt.figure(figsize=(10, 8))
sns.boxplot(x="Q006", y= "NU_NOTA_TOTAL", data = dados_sem_notas_zero, order = renda_ordenada)
plt.title("Boxplot das notas totais pela renda familiar", fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0415df568a79> in <module>()
#       3
#       4 plt.figure(figsize=(10, 8))
# ----> 5 sns.boxplot(x="Q006", y= "NU_NOTA_TOTAL", data = dados_sem_notas_zero, order = renda_ordenada)
#       6 plt.title("Boxplot das notas totais pela renda familiar", fontsize=20)
#
# NameError: name 'renda_ordenada' is not defined

# %%
renda_ordenada = dados["Q006"].unique()
renda_ordenada.sort()

plt.figure(figsize=(10, 8))
sns.boxplot(x="Q006", y= "NU_NOTA_MT", data = dados, order = renda_ordenada)
plt.title("Boxplot das notas de matemática pela renda familiar", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matemática pela renda familiar')

# %%
dados_sem_notas_zero = dados.query("NU_NOTA_TOTAL != 0")
renda_ordenada = dados["Q006"].unique()
dados_sem_notas_zero.head()

plt.figure(figsize=(14, 8))
sns.boxplot(x="Q006", y= "NU_NOTA_TOTAL", data = dados_sem_notas_zero,  hue = "IN_TREINEIRO", order = renda_ordenada)
plt.title("Boxplot das notas totais pela renda familiar", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Boxplot das notas totais pela renda familiar')

# %% [markdown]
# ### Aula 3

# %%
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL")

# %%
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_MT")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True)

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="density",  cumulative=True)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data = dados_sem_notas_zero, x="NU_NOTA_MT", y="NU_NOTA_LC")
plt.xlim((1, 1050))
plt.ylim((1, 1050))
# Out:
# (1.0, 1050.0)

# %%
sns.pairplot(dados_sem_notas_zero[provas])

# %%
correlacao = dados_sem_notas_zero[provas].corr()

# %%
correlacao
# Out:
#                  NU_NOTA_REDACAO  NU_NOTA_CH  ...  NU_NOTA_LC  NU_NOTA_CN
# NU_NOTA_REDACAO         1.000000    0.528338  ...    0.535797    0.504740
# NU_NOTA_CH              0.528338    1.000000  ...    0.744170    0.668979
# NU_NOTA_MT              0.493046    0.610332  ...    0.587710    0.649527
# NU_NOTA_LC              0.535797    0.744170  ...    1.000000    0.641624
# NU_NOTA_CN              0.504740    0.668979  ...    0.641624    1.000000
#
# [5 rows x 5 columns]

# %%
sns.heatmap(correlacao, cmap="Blues", center = 0, annot=True)
